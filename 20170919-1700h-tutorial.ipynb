# %% [markdown]
# try.jupyter.org

# %%
grades = [70, 85, 90]

# %%
grades[0]
# Out:
# 70

# %%
dir(grades)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
help(grades.insert)
# Out:
# Help on built-in function insert:
#
# insert(...) method of builtins.list instance
#     L.insert(index, object) -- insert object before index

# %%
grades
# Out:
# [70, 85, 90]

# %%
grades.insert(0, 80)

# %%
grades
# Out:
# [80, 70, 85, 90]

# %% [markdown]
# ### Exercise 3
#
# Your list grades currently looks like:
#
#     [80, 70, 85, 90]
#
# Try and get your list to look like this:
#
#     [70, 80, 90]
#
# Hint: You will need to use two list methods

# %%
dir(grades)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
grades
# Out:
# [80, 70, 85, 90]

# %%
grades.remove(85)

# %%
grades
# Out:
# [80, 70, 90]

# %%
grades.sort(key=int)

# %%
grades
# Out:
# [70, 80, 90]

# %%
for name in grades:
    print(name)
# Out:
# 70
# 80
# 90

# %% [markdown]
# ### Exercise 4
#
#     my_first_list = ['orange', 'kiwi']
#
#     my_second_list = ['apple', 'banana']
#
# Write a function that will add every item from my_first_list to my_second_list and will sort them alphabetically.
#
# my_second_list = ['apple', 'banana', 'kiwi', 'orange']
#
# def function_name(parameter, parameter2):
#
# for item in parameter:
#
# add item to parameter 2
#
# sort parameter 2
#
# return parameter 2

# %%
def new_list_magic(original_list, new_list):
    for item in original_list:
        new_list.append(item)
        new_list.sort()
    return(new_list)

# %%
my_first_list = ['orange', 'kiwi']
my_second_list = ['apple', 'banana']

# %%
new_list_magic(my_first_list, my_second_list)
# Out:
# ['apple', 'banana', 'kiwi', 'orange']

# %%
my_second_list
# Out:
# ['apple', 'banana', 'kiwi', 'orange']

# %%
grade = 60
if grade >= 60:
    print("Passing grade")
# Out:
# Passing grade

# %%
grade = 50
if grade >= 60:
    print("Passing grade")

# %%
if grade >= 60:
    print("passing grade")
else:
    print("failing grade")
# Out:
# failing grade

# %%
grade = 70

if grade >= 90:
    print("A grade")

elif grade >=80:
    print("B grade")

elif grade >=70:
    print("C grade")

elif grade >= 65:
    print("D grade")

else:
    print("Failing grade")
# Out:
# C grade

# %% [markdown]
# ### Exercise 5
#
# For the following list:
#
#     wordlist = ['soap', 'baby', 'tape', 'car']
#
# Check to see if the item starts with the letter s, t, or b.
#
# If the word starts with s or t, add it to a list called ```st_words.```
#
# If the word starts with b, add it to a list called ```b_words.```
#
# For all other words, indicate to the user that the word does not start with b, s, or t.
#
# Hint: You have to create an empty list for ```st_words``` and ```b_words```.
#
# Hint 2: Use ```dir()``` to find out what string functions you can use to write your conditions. - Use the append method to add a list item to b_words or st_words
#
# Hint 3: Use a for loop to loop through each item in the list, and in your for loop use if statements to check what the first letter is in your list, add the item if it starts with b, s, or t

# %%
wordlist = ['soap', 'baby', 'tape', 'car']

# %%
st_words = []
b_words = []

# %%
for item in wordlist:
    if item.startswith('b'):
        b_words.append(item)
    elif item.startswith('s') or item.startswith('t'):
        st_words.append(item)
    else:
        print(item, 'does not start with b, s, or t')
# Out:
# car does not start with b, s, or t

# %%
b_words
# Out:
# ['baby']

# %%
st_words
# Out:
# ['soap', 'tape']

# %%
x = 5
while x > 0:
    print(x)
    x = x - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
x
# Out:
# 0

# %%
x = 5
y = x

while y > 0:
    print(y)
    y = y - 1
else:
    print(x)
# Out:
# 5
# 4
# 3
# 2
# 1
# 5

# %%
Use break statements to stop a while loop
else will let you run through the entire loop then do this additional thing, or if your while loop is false runs the else
